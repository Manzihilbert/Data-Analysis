# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
violence = pd.read_excel('crsv_data.xlsx')
violence
# Out:
#                      Date                                  Event Description  \
# 0         #date +occurred                                                NaN
# 1     2023-08-10 00:00:00  August 2023: In South Kivu province, two women...
# 2     2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 3     2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 4     2023-08-05 00:00:00  August 2023: In North Kivu province, a woman w...
# ...                   ...                                                ...
# 1013  2020-01-31 00:00:00  January 2020: In North Darfur state, six women...
# 1014  2020-01-16 00:00:00  January 2020: In North Darfur state, a young g...
# 1015  2020-01-11 00:00:00  January 2020: In the outskirts of Yei city, Ye...
# 1016  2020-01-07 00:00:00  January 2020: In Lakes state, three girls betw...
# 1017  2020-01-01 00:00:00  September 2020: In Uttar Pradesh state, a teac...
#
# ...

# %%
violence.shape
# Out:
# (1018, 22)

# %%
violence.dtypes
# Out:
# Date                                              object
# Event Description                                 object
# Country                                           object
# Country ISO                                       object
# Admin 1                                           object
# Latitude                                          object
# Longitude                                         object
# Geo Precision                                     object
# Location Where Sexual Violence Was Committed      object
# Reported Perpetrator                              object
# Perpetrator Group Name                            object
# Single And Group Perpetrators                     object
# Weapon Carried/Used                               object
# Survivor or Victim                                object
# Survivor Or Victim Sex                            object
# Adult or Minor                                    object
# ...

# %%
violence.describe()
# Out:
#        Reported Deaths Following the Sexual Violence  SIND Event ID
# count                                     108.000000    1017.000000
# mean                                        1.601852   32884.370698
# std                                         1.570403    4367.862318
# min                                         1.000000   25197.000000
# 25%                                         1.000000   30444.000000
# 50%                                         1.000000   31537.000000
# 75%                                         1.000000   37318.000000
# max                                        10.000000   40597.000000

# %%
violence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 22 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Date                                           1018 non-null   object
#  1   Event Description                              1017 non-null   object
#  2   Country                                        1018 non-null   object
#  3   Country ISO                                    1018 non-null   object
#  4   Admin 1                                        1018 non-null   object
#  5   Latitude                                       1016 non-null   object
#  6   Longitude                                      1016 non-null   object
#  7   Geo Precision                                  1017 non-null   object
#  8   Location Where Sexual Violence Was Committed   1018 non-null   object
# ...

# %%
violence.isnull().sum()
# Out:
# Date                                               0
# Event Description                                  1
# Country                                            0
# Country ISO                                        0
# Admin 1                                            0
# Latitude                                           2
# Longitude                                          2
# Geo Precision                                      1
# Location Where Sexual Violence Was Committed       0
# Reported Perpetrator                               0
# Perpetrator Group Name                             0
# Single And Group Perpetrators                      0
# Weapon Carried/Used                                0
# Survivor or Victim                                 0
# Survivor Or Victim Sex                             0
# Adult or Minor                                     0
# Type                                               0
# SV Context                                        12
# ...

# %%
violence.rename(columns={'Reported Deaths Following the Sexual Violence':'Deaths'},inplace=True)

# %%
violence.isnull().sum()
# Out:
# Date                                              0
# Event Description                                 1
# Country                                           0
# Country ISO                                       0
# Admin 1                                           0
# Latitude                                          2
# Longitude                                         2
# Geo Precision                                     1
# Location Where Sexual Violence Was Committed      0
# Reported Perpetrator                              0
# Perpetrator Group Name                            0
# Single And Group Perpetrators                     0
# Weapon Carried/Used                               0
# Survivor or Victim                                0
# Survivor Or Victim Sex                            0
# Adult or Minor                                    0
# Type                                              0
# SV Context                                       12
# ...

# %%
violence['Deaths'].value_counts()
# Out:
# Deaths
# 1.0     83
# 2.0     13
# 3.0      5
# 6.0      3
# 8.0      2
# 5.0      1
# 10.0     1
# Name: count, dtype: int64

# %%
violence['Deaths'].median()
# Out:
# 1.0

# %%
violence['Deaths'] = violence['Deaths'].fillna(violence['Deaths'].median())

# %%
violence.isnull().sum()
# Out:
# Date                                             0
# Event Description                                1
# Country                                          0
# Country ISO                                      0
# Admin 1                                          0
# Latitude                                         2
# Longitude                                        2
# Geo Precision                                    1
# Location Where Sexual Violence Was Committed     0
# Reported Perpetrator                             0
# Perpetrator Group Name                           0
# Single And Group Perpetrators                    0
# Weapon Carried/Used                              0
# Survivor or Victim                               0
# Survivor Or Victim Sex                           0
# Adult or Minor                                   0
# Type                                             0
# SV Context                                      12
# ...

# %%
violence['Number of Reported Victims'] = violence['Number of Reported Victims'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/manzi/Data-Analysis/violence/violence.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/home/manzi/Data-Analysis/violence/violence.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> violence['Number of Reported Victims'] = violence['Number of Reported Victims'].astype(int)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
violence.head()
# Out:
#                   Date                                  Event Description  \
# 1  2023-08-10 00:00:00  August 2023: In South Kivu province, two women...
# 2  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 3  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 4  2023-08-05 00:00:00  August 2023: In North Kivu province, a woman w...
# 5  2023-07-31 00:00:00  July 2023: In West Darfur state, a Massalit wo...
#
#   Country Country ISO            Admin 1   Latitude  Longitude  \
# 1     DRC         COD         South Kivu  -2.108899  28.910531
# 2     DRC         COD         Tanganyika  -6.443589  29.025879
# 3     DRC         COD         Tanganyika  -6.429942  29.028608
# 4     DRC         COD         North Kivu  -1.184379  29.450907
# 5   Sudan         SDN  West Darfur State  13.436374  22.443698
#
#                                Geo Precision  \
# 1  (3) District, Communicipality or Commune
# 2                       (2) 25 km Precision
# ...

# %%
violence = violence.drop(0) #this drops a row
# Out:
#                   Date                                  Event Description  \
# 1  2023-08-10 00:00:00  August 2023: In South Kivu province, two women...
# 2  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 3  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 4  2023-08-05 00:00:00  August 2023: In North Kivu province, a woman w...
# 5  2023-07-31 00:00:00  July 2023: In West Darfur state, a Massalit wo...
#
#   Country Country ISO            Admin 1   Latitude  Longitude  \
# 1     DRC         COD         South Kivu  -2.108899  28.910531
# 2     DRC         COD         Tanganyika  -6.443589  29.025879
# 3     DRC         COD         Tanganyika  -6.429942  29.028608
# 4     DRC         COD         North Kivu  -1.184379  29.450907
# 5   Sudan         SDN  West Darfur State  13.436374  22.443698
#
#                                Geo Precision  \
# 1  (3) District, Communicipality or Commune
# 2                       (2) 25 km Precision
# ...

# %%
violence.head()
# Out:
#                   Date                                  Event Description  \
# 1  2023-08-10 00:00:00  August 2023: In South Kivu province, two women...
# 2  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 3  2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 4  2023-08-05 00:00:00  August 2023: In North Kivu province, a woman w...
# 5  2023-07-31 00:00:00  July 2023: In West Darfur state, a Massalit wo...
#
#   Country Country ISO            Admin 1   Latitude  Longitude  \
# 1     DRC         COD         South Kivu  -2.108899  28.910531
# 2     DRC         COD         Tanganyika  -6.443589  29.025879
# 3     DRC         COD         Tanganyika  -6.429942  29.028608
# 4     DRC         COD         North Kivu  -1.184379  29.450907
# 5   Sudan         SDN  West Darfur State  13.436374  22.443698
#
#                                Geo Precision  \
# 1  (3) District, Communicipality or Commune
# 2                       (2) 25 km Precision
# ...

# %%
violence.dtypes
# Out:
# Date                                             object
# Event Description                                object
# Country                                          object
# Country ISO                                      object
# Admin 1                                          object
# Latitude                                         object
# Longitude                                        object
# Geo Precision                                    object
# Location Where Sexual Violence Was Committed     object
# Reported Perpetrator                             object
# Perpetrator Group Name                           object
# Single And Group Perpetrators                    object
# Weapon Carried/Used                              object
# Survivor or Victim                               object
# Survivor Or Victim Sex                           object
# Adult or Minor                                   object
# Type                                             object
# ...

# %%
violence['Number of Reported Victims'] = violence['Number of Reported Victims'].astype(int)

# %%
violence.dtypes
# Out:
# Date                                             object
# Event Description                                object
# Country                                          object
# Country ISO                                      object
# Admin 1                                          object
# Latitude                                         object
# Longitude                                        object
# Geo Precision                                    object
# Location Where Sexual Violence Was Committed     object
# Reported Perpetrator                             object
# Perpetrator Group Name                           object
# Single And Group Perpetrators                    object
# Weapon Carried/Used                              object
# Survivor or Victim                               object
# Survivor Or Victim Sex                           object
# Adult or Minor                                   object
# Type                                             object
# ...

# %%
violence.rename(columns={'Number of Reported Victims':'victims'},inplace=True) #renaming columns

# %%
violence
# Out:
#                      Date                                  Event Description  \
# 1     2023-08-10 00:00:00  August 2023: In South Kivu province, two women...
# 2     2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 3     2023-08-08 00:00:00  August 2023: In Tanganyika province, an unspec...
# 4     2023-08-05 00:00:00  August 2023: In North Kivu province, a woman w...
# 5     2023-07-31 00:00:00  July 2023: In West Darfur state, a Massalit wo...
# ...                   ...                                                ...
# 1013  2020-01-31 00:00:00  January 2020: In North Darfur state, six women...
# 1014  2020-01-16 00:00:00  January 2020: In North Darfur state, a young g...
# 1015  2020-01-11 00:00:00  January 2020: In the outskirts of Yei city, Ye...
# 1016  2020-01-07 00:00:00  January 2020: In Lakes state, three girls betw...
# 1017  2020-01-01 00:00:00  September 2020: In Uttar Pradesh state, a teac...
#
# ...

# %%
sns.countplot(data=violence, x='Deaths')
# Out:
# <Axes: xlabel='Deaths', ylabel='count'>

# %%
violence.dtypes
# Out:
# Date                                             object
# Event Description                                object
# Country                                          object
# Country ISO                                      object
# Admin 1                                          object
# Latitude                                         object
# Longitude                                        object
# Geo Precision                                    object
# Location Where Sexual Violence Was Committed     object
# Reported Perpetrator                             object
# Perpetrator Group Name                           object
# Single And Group Perpetrators                    object
# Weapon Carried/Used                              object
# Survivor or Victim                               object
# Survivor Or Victim Sex                           object
# Adult or Minor                                   object
# Type                                             object
# ...

# %%
violence.rename(columns={'Location Where Sexual Violence Was Committed':'location','Single And Group Perpetrators':'perpetrator'},inplace=True)

# %%
violence.columns
# Out:
# Index(['Date', 'Event Description', 'Country', 'Country ISO', 'Admin 1',
#        'Latitude', 'Longitude', 'Geo Precision', 'location',
#        'Reported Perpetrator', 'Perpetrator Group Name', 'perpetrator',
#        'Weapon Carried/Used', 'Survivor or Victim', 'Survivor Or Victim Sex',
#        'Adult or Minor ', 'Type', 'SV Context', 'Classification',
#        'Number of Reported Victims', 'Deaths', 'SIND Event ID'],
#       dtype='object')

# %%
#is there a significant increase in the use of firearms by group perpetrators to commit rape against female adults between 2020 and 2023?
#understanding the data
violence['perpetrator'].value_counts()
# Out:
# perpetrator
# Group Perpetrator     773
# Single Serpetrator    210
# No Information         27
# Multiple                6
# #group +size            1
# Other                   1
# Name: count, dtype: int64

# %%
violence['Survivor or Victim'].value_counts()
# Out:
# Survivor or Victim
# Civilian                   984
# Health Worker               16
# Aid Worker                   8
# Educator                     5
# Health Worker, Civilian      3
# #survivor_victim             1
# Civilian, Educator           1
# Name: count, dtype: int64

# %%
violence['Survivor Or Victim Sex'].value_counts()
# Out:
# Survivor Or Victim Sex
# Female                   919
# Male                      45
# Unclear                   25
# ProbablyFemale            14
# Female, Male               8
# NotApplicable              2
# ProbablyMale               2
# #sex                       1
# Female, Male, Unclear      1
# Female, Unclear            1
# Name: count, dtype: int64

# %%
violence['Weapon Carried/Used'].value_counts()
# Out:
# Weapon Carried/Used
# Firearms                                                             847
# Knife                                                                 63
# No Information on the Weapon Used                                     30
# Not Applicable: No Direct Violence                                    24
# Unarmed Perpetrator                                                   19
# Arson                                                                 18
# Fist and Foot                                                         13
# #weapons                                                               1
# Hand Grenade                                                           1
# Other Weapon                                                           1
# Firearms, Not Applicable: No Direct Violence, Unarmed Perpetrator      1
# Name: count, dtype: int64

# %%
#getting neccesary columns
violence_analysis = violence[['Date','location','perpetrator','Weapon Carried/Used','Survivor Or Victim Sex','Survivor Or Victim Sex']]

# %%
violence_analysis.head()
# Out:
#                   Date               location        perpetrator  \
# 0      #date +occurred                   #loc       #group +size
# 1  2023-08-10 00:00:00  Street, Road or Field  Group Perpetrator
# 2  2023-08-08 00:00:00         No Information  Group Perpetrator
# 3  2023-08-08 00:00:00         No Information  Group Perpetrator
# 4  2023-08-05 00:00:00         No Information  Group Perpetrator
#
#   Weapon Carried/Used Survivor Or Victim Sex Survivor Or Victim Sex
# 0            #weapons                   #sex                   #sex
# 1            Firearms                 Female                 Female
# 2               Knife                 Female                 Female
# 3               Knife                 Female                 Female
# 4            Firearms                 Female                 Female

# %%
violence_analysis.dtypes
# Out:
# Date                      object
# location                  object
# perpetrator               object
# Weapon Carried/Used       object
# Survivor Or Victim Sex    object
# Survivor Or Victim Sex    object
# dtype: object

# %%
#violence_analysis['Date'] = pd.to_datetime(violence_analysis['Date'])
violence_analysis['Date']
# Out:
# 0           #date +occurred
# 1       2023-08-10 00:00:00
# 2       2023-08-08 00:00:00
# 3       2023-08-08 00:00:00
# 4       2023-08-05 00:00:00
#                ...
# 1013    2020-01-31 00:00:00
# 1014    2020-01-16 00:00:00
# 1015    2020-01-11 00:00:00
# 1016    2020-01-07 00:00:00
# 1017    2020-01-01 00:00:00
# Name: Date, Length: 1018, dtype: object
